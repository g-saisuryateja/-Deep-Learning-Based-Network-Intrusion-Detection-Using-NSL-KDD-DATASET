# %% [markdown]
# # Network Intrusion Detection using SimpleRNN

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, SimpleRNN, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from keras.utils.vis_utils import plot_model

# %% [markdown]
# ### Reading Data

# %%
#Add the column labels
feature=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count", 
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

# %% [markdown]
# ### Fetching the files

# %%
train='KDDTrain+.txt'
test='KDDTest+.txt'
test21='KDDTest-21.txt'

train_data=pd.read_csv(train,names=feature)
test_data=pd.read_csv(test,names=feature)
test_data21 = pd.read_csv(test21, names= feature)
data= pd.concat([train_data, test_data], ignore_index=True)

# %%
data.head(5)
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      label  difficulty
# 0   normal          20
# 1   normal          15
# 2  neptune          19
# 3   normal          21
# 4   normal          21
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Exploring Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
#  42  difficulty                   148517 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 48.7+ MB

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 47.6+ MB

# %%
data.describe().T
# Out:
#                                 count          mean           std  min    25%  \
# duration                     148517.0    276.779305  2.460683e+03  0.0   0.00
# src_bytes                    148517.0  40227.949299  5.409612e+06  0.0   0.00
# dst_bytes                    148517.0  17088.853593  3.703525e+06  0.0   0.00
# land                         148517.0      0.000215  1.467714e-02  0.0   0.00
# wrong_fragment               148517.0      0.020523  2.400691e-01  0.0   0.00
# urgent                       148517.0      0.000202  1.941708e-02  0.0   0.00
# hot                          148517.0      0.189379  2.013160e+00  0.0   0.00
# num_failed_logins            148517.0      0.004323  7.224823e-02  0.0   0.00
# logged_in                    148517.0      0.402789  4.904606e-01  0.0   0.00
# num_compromised              148517.0      0.255062  2.223137e+01  0.0   0.00
# root_shell                   148517.0      0.001508  3.880696e-02  0.0   0.00
# su_attempted                 148517.0      0.000976  4.238907e-02  0.0   0.00
# num_root                     148517.0      0.273726  2.268902e+01  0.0   0.00
# num_file_creations           148517.0      0.012073  5.178631e-01  0.0   0.00
# num_shells                   148517.0      0.000525  2.770051e-02  0.0   0.00
# num_access_files             148517.0      0.004013  9.525663e-02  0.0   0.00
# num_outbound_cmds            148517.0      0.000000  0.000000e+00  0.0   0.00
# is_host_login                148517.0      0.000081  8.988484e-03  0.0   0.00
# is_guest_login               148517.0      0.012308  1.102585e-01  0.0   0.00
# count                        148517.0     83.336561  1.167607e+02  0.0   2.00
# srv_count                    148517.0     28.251937  7.536963e+01  0.0   2.00
# serror_rate                  148517.0      0.256925  4.319178e-01  0.0   0.00
# srv_serror_rate              148517.0      0.255337  4.325783e-01  0.0   0.00
# rerror_rate                  148517.0      0.137947  3.393872e-01  0.0   0.00
# srv_rerror_rate              148517.0      0.138487  3.417829e-01  0.0   0.00
# same_srv_rate                148517.0      0.672983  4.365437e-01  0.0   0.10
# diff_srv_rate                148517.0      0.067761  1.946658e-01  0.0   0.00
# srv_diff_host_rate           148517.0      0.097441  2.588856e-01  0.0   0.00
# dst_host_count               148517.0    183.928042  9.852833e+01  0.0  87.00
# dst_host_srv_count           148517.0    119.462661  1.112323e+02  0.0  11.00
# dst_host_same_srv_rate       148517.0      0.534521  4.480612e-01  0.0   0.05
# dst_host_diff_srv_rate       148517.0      0.084103  1.941020e-01  0.0   0.00
# dst_host_same_src_port_rate  148517.0      0.145932  3.086376e-01  0.0   0.00
# dst_host_srv_diff_host_rate  148517.0      0.030584  1.089751e-01  0.0   0.00
# dst_host_serror_rate         148517.0      0.256122  4.284996e-01  0.0   0.00
# dst_host_srv_serror_rate     148517.0      0.251304  4.297194e-01  0.0   0.00
# dst_host_rerror_rate         148517.0      0.136220  3.227411e-01  0.0   0.00
# dst_host_srv_rerror_rate     148517.0      0.136397  3.352823e-01  0.0   0.00
#
#                                 50%     75%           max
# duration                       0.00    0.00  5.771500e+04
# src_bytes                     44.00  278.00  1.379964e+09
# dst_bytes                      0.00  571.00  1.309937e+09
# land                           0.00    0.00  1.000000e+00
# wrong_fragment                 0.00    0.00  3.000000e+00
# urgent                         0.00    0.00  3.000000e+00
# hot                            0.00    0.00  1.010000e+02
# num_failed_logins              0.00    0.00  5.000000e+00
# logged_in                      0.00    1.00  1.000000e+00
# num_compromised                0.00    0.00  7.479000e+03
# root_shell                     0.00    0.00  1.000000e+00
# su_attempted                   0.00    0.00  2.000000e+00
# num_root                       0.00    0.00  7.468000e+03
# num_file_creations             0.00    0.00  1.000000e+02
# num_shells                     0.00    0.00  5.000000e+00
# num_access_files               0.00    0.00  9.000000e+00
# num_outbound_cmds              0.00    0.00  0.000000e+00
# is_host_login                  0.00    0.00  1.000000e+00
# is_guest_login                 0.00    0.00  1.000000e+00
# count                         13.00  141.00  5.110000e+02
# srv_count                      7.00   17.00  5.110000e+02
# serror_rate                    0.00    0.85  1.000000e+00
# srv_serror_rate                0.00    0.91  1.000000e+00
# rerror_rate                    0.00    0.00  1.000000e+00
# srv_rerror_rate                0.00    0.00  1.000000e+00
# same_srv_rate                  1.00    1.00  1.000000e+00
# diff_srv_rate                  0.00    0.06  1.000000e+00
# srv_diff_host_rate             0.00    0.00  1.000000e+00
# dst_host_count               255.00  255.00  2.550000e+02
# dst_host_srv_count            72.00  255.00  2.550000e+02
# dst_host_same_srv_rate         0.60    1.00  1.000000e+00
# dst_host_diff_srv_rate         0.02    0.07  1.000000e+00
# dst_host_same_src_port_rate    0.00    0.05  1.000000e+00
# dst_host_srv_diff_host_rate    0.00    0.01  1.000000e+00
# dst_host_serror_rate           0.00    0.60  1.000000e+00
# dst_host_srv_serror_rate       0.00    0.50  1.000000e+00
# dst_host_rerror_rate           0.00    0.00  1.000000e+00
# dst_host_srv_rerror_rate       0.00    0.00  1.000000e+00

# %%
# number of attack labels 
data['label'].value_counts()
# Out:
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: label, dtype: int64

# %% [markdown]
# ### Redistribute across common attack class

# %%
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# normal    77054
# Dos       53387
# Probe     14077
# R2L        3880
# U2R         119
# Name: label, dtype: int64

# %% [markdown]
# ### Creating Multi-class labels

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
label = pd.DataFrame(data.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = label.apply(le2.fit_transform)
data['intrusion'] = enc_label
print(data.shape)
data.head(5)
# Out:
# (148517, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes     land  \
# 0 -0.112481           tcp  ftp_data   SF  -0.007346  -0.004614 -0.01468
# 1 -0.112481           udp     other   SF  -0.007409  -0.004614 -0.01468
# 2 -0.112481           tcp   private   S0  -0.007436  -0.004614 -0.01468
# 3 -0.112481           tcp      http   SF  -0.007394  -0.002413 -0.01468
# 4 -0.112481           tcp      http   SF  -0.007400  -0.004501 -0.01468
#
#    wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0       -0.085488 -0.010403 -0.094071  ...               -0.813554
# 1       -0.085488 -0.010403 -0.094071  ...               -1.192968
# 2       -0.085488 -0.010403 -0.094071  ...               -0.969783
# 3       -0.085488 -0.010403 -0.094071  ...                1.038878
# 4       -0.085488 -0.010403 -0.094071  ...                1.038878
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0               -0.278736                     0.077981
# 1                2.657874                     2.378421
# 2               -0.175697                    -0.472829
# 3               -0.433294                    -0.375627
# 4               -0.433294                    -0.472829
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                    -0.280650             -0.597720
# 1                    -0.280650             -0.597720
# 2                    -0.280650              1.736012
# 3                     0.086408             -0.527708
# 4                    -0.280650             -0.597720
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                 -0.584813             -0.267151                 -0.406815
# 1                 -0.584813             -0.422074                 -0.406815
# 2                  1.742295             -0.422074                 -0.406815
# 3                 -0.561542             -0.422074                 -0.376989
# 4                 -0.584813             -0.422074                 -0.406815
#
#     label  intrusion
# 0  normal          4
# 1  normal          4
# 2     Dos          0
# 3  normal          4
# 4  normal          4
#
# [5 rows x 43 columns]

# %%
data.drop(labels= ['label'], axis=1, inplace=True)
print(data.shape)
# Out:
# (148517, 42)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")  
print(data.shape)
# Out:
# (148517, 123)

# %%
y_data= data['intrusion']
X_data= data.drop(labels=['intrusion'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (148517, 122)
# y_train has shape: (148517,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
# splitting the dataset 80% for training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (118813, 122)
#  (29704, 122)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %% [markdown]
# ### Applying SimpleRNN Algorithms

# %%
model = Sequential() # initializing model
model.add(SimpleRNN(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(SimpleRNN(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(SimpleRNN(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))

# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 64)             11968
#
#  dropout (Dropout)           (None, 1, 64)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 1, 64)             8256
#
#  dropout_1 (Dropout)         (None, 1, 64)             0
#
#  simple_rnn_2 (SimpleRNN)    (None, 1, 64)             8256
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 31,985
# Trainable params: 31,985
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  Training the model

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 6s 82ms/step - loss: 0.8128 - accuracy: 0.7314 - val_loss: 0.3741 - val_accuracy: 0.9021
# Epoch 2/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.3319 - accuracy: 0.9084 - val_loss: 0.2453 - val_accuracy: 0.9273
# Epoch 3/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.2477 - accuracy: 0.9238 - val_loss: 0.1970 - val_accuracy: 0.9424
# Epoch 4/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2088 - accuracy: 0.9344 - val_loss: 0.1663 - val_accuracy: 0.9440
# Epoch 5/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.1816 - accuracy: 0.9402 - val_loss: 0.1415 - val_accuracy: 0.9490
# Epoch 6/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1616 - accuracy: 0.9451 - val_loss: 0.1229 - val_accuracy: 0.9556
# Epoch 7/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.1439 - accuracy: 0.9519 - val_loss: 0.1108 - val_accuracy: 0.9603
# Epoch 8/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.1322 - accuracy: 0.9552 - val_loss: 0.1022 - val_accuracy: 0.9677
# Epoch 9/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.1238 - accuracy: 0.9583 - val_loss: 0.0956 - val_accuracy: 0.9698
# Epoch 10/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1199 - accuracy: 0.9592 - val_loss: 0.0901 - val_accuracy: 0.9710
# Epoch 11/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1118 - accuracy: 0.9628 - val_loss: 0.0870 - val_accuracy: 0.9717
# Epoch 12/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.1071 - accuracy: 0.9635 - val_loss: 0.0836 - val_accuracy: 0.9716
# Epoch 13/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1042 - accuracy: 0.9645 - val_loss: 0.0808 - val_accuracy: 0.9742
# Epoch 14/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.1007 - accuracy: 0.9655 - val_loss: 0.0783 - val_accuracy: 0.9740
# Epoch 15/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0968 - accuracy: 0.9671 - val_loss: 0.0765 - val_accuracy: 0.9740
# Epoch 16/100
# 20/20 [==============================] - 1s 54ms/step - loss: 0.0951 - accuracy: 0.9670 - val_loss: 0.0744 - val_accuracy: 0.9747
# Epoch 17/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0942 - accuracy: 0.9679 - val_loss: 0.0723 - val_accuracy: 0.9752
# Epoch 18/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0899 - accuracy: 0.9695 - val_loss: 0.0716 - val_accuracy: 0.9754
# Epoch 19/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0872 - accuracy: 0.9697 - val_loss: 0.0704 - val_accuracy: 0.9763
# Epoch 20/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0850 - accuracy: 0.9709 - val_loss: 0.0685 - val_accuracy: 0.9766
# Epoch 21/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0853 - accuracy: 0.9700 - val_loss: 0.0670 - val_accuracy: 0.9769
# Epoch 22/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0825 - accuracy: 0.9712 - val_loss: 0.0666 - val_accuracy: 0.9773
# Epoch 23/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0818 - accuracy: 0.9718 - val_loss: 0.0652 - val_accuracy: 0.9776
# Epoch 24/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0804 - accuracy: 0.9722 - val_loss: 0.0651 - val_accuracy: 0.9786
# Epoch 25/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0808 - accuracy: 0.9724 - val_loss: 0.0646 - val_accuracy: 0.9784
# Epoch 26/100
# 20/20 [==============================] - 1s 48ms/step - loss: 0.0785 - accuracy: 0.9730 - val_loss: 0.0637 - val_accuracy: 0.9789
# Epoch 27/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.0781 - accuracy: 0.9735 - val_loss: 0.0632 - val_accuracy: 0.9790
# Epoch 28/100
# 20/20 [==============================] - 1s 51ms/step - loss: 0.0754 - accuracy: 0.9748 - val_loss: 0.0635 - val_accuracy: 0.9792
# Epoch 29/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0752 - accuracy: 0.9750 - val_loss: 0.0621 - val_accuracy: 0.9789
# Epoch 30/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0733 - accuracy: 0.9749 - val_loss: 0.0609 - val_accuracy: 0.9803
# Epoch 31/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0734 - accuracy: 0.9755 - val_loss: 0.0591 - val_accuracy: 0.9798
# Epoch 32/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0706 - accuracy: 0.9764 - val_loss: 0.0590 - val_accuracy: 0.9810
# Epoch 33/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.0708 - accuracy: 0.9761 - val_loss: 0.0581 - val_accuracy: 0.9809
# Epoch 34/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0701 - accuracy: 0.9760 - val_loss: 0.0582 - val_accuracy: 0.9800
# Epoch 35/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0700 - accuracy: 0.9761 - val_loss: 0.0580 - val_accuracy: 0.9822
# Epoch 36/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0699 - accuracy: 0.9761 - val_loss: 0.0581 - val_accuracy: 0.9803
# Epoch 37/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0699 - accuracy: 0.9767 - val_loss: 0.0582 - val_accuracy: 0.9813
# Epoch 38/100
# 20/20 [==============================] - 1s 54ms/step - loss: 0.0699 - accuracy: 0.9764 - val_loss: 0.0574 - val_accuracy: 0.9809
# Epoch 39/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0664 - accuracy: 0.9776 - val_loss: 0.0557 - val_accuracy: 0.9817
# Epoch 40/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0677 - accuracy: 0.9772 - val_loss: 0.0557 - val_accuracy: 0.9826
# Epoch 41/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0654 - accuracy: 0.9781 - val_loss: 0.0547 - val_accuracy: 0.9836
# Epoch 42/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0645 - accuracy: 0.9783 - val_loss: 0.0551 - val_accuracy: 0.9818
# Epoch 43/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0635 - accuracy: 0.9787 - val_loss: 0.0534 - val_accuracy: 0.9835
# Epoch 44/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0637 - accuracy: 0.9788 - val_loss: 0.0540 - val_accuracy: 0.9817
# Epoch 45/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0630 - accuracy: 0.9789 - val_loss: 0.0530 - val_accuracy: 0.9834
# Epoch 46/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.0633 - accuracy: 0.9780 - val_loss: 0.0531 - val_accuracy: 0.9833
# Epoch 47/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0611 - accuracy: 0.9794 - val_loss: 0.0526 - val_accuracy: 0.9840
# Epoch 48/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0611 - accuracy: 0.9795 - val_loss: 0.0525 - val_accuracy: 0.9821
# Epoch 49/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0612 - accuracy: 0.9792 - val_loss: 0.0517 - val_accuracy: 0.9829
# Epoch 50/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0616 - accuracy: 0.9800 - val_loss: 0.0510 - val_accuracy: 0.9833
# Epoch 51/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0606 - accuracy: 0.9793 - val_loss: 0.0513 - val_accuracy: 0.9829
# Epoch 52/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0589 - accuracy: 0.9804 - val_loss: 0.0501 - val_accuracy: 0.9843
# Epoch 53/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0603 - accuracy: 0.9795 - val_loss: 0.0530 - val_accuracy: 0.9836
# Epoch 54/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0638 - accuracy: 0.9786 - val_loss: 0.0499 - val_accuracy: 0.9838
# Epoch 55/100
# 20/20 [==============================] - 1s 56ms/step - loss: 0.0572 - accuracy: 0.9811 - val_loss: 0.0496 - val_accuracy: 0.9844
# Epoch 56/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0581 - accuracy: 0.9803 - val_loss: 0.0491 - val_accuracy: 0.9835
# Epoch 57/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0554 - accuracy: 0.9814 - val_loss: 0.0487 - val_accuracy: 0.9831
# Epoch 58/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0566 - accuracy: 0.9806 - val_loss: 0.0488 - val_accuracy: 0.9846
# Epoch 59/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0552 - accuracy: 0.9812 - val_loss: 0.0481 - val_accuracy: 0.9851
# Epoch 60/100
# 20/20 [==============================] - 1s 56ms/step - loss: 0.0570 - accuracy: 0.9806 - val_loss: 0.0484 - val_accuracy: 0.9841
# Epoch 61/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0564 - accuracy: 0.9814 - val_loss: 0.0484 - val_accuracy: 0.9839
# Epoch 62/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0560 - accuracy: 0.9809 - val_loss: 0.0481 - val_accuracy: 0.9838
# Epoch 63/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0552 - accuracy: 0.9820 - val_loss: 0.0477 - val_accuracy: 0.9834
# Epoch 64/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0552 - accuracy: 0.9818 - val_loss: 0.0478 - val_accuracy: 0.9845
# Epoch 65/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0554 - accuracy: 0.9812 - val_loss: 0.0462 - val_accuracy: 0.9862
# Epoch 66/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0554 - accuracy: 0.9809 - val_loss: 0.0486 - val_accuracy: 0.9842
# Epoch 67/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0546 - accuracy: 0.9819 - val_loss: 0.0465 - val_accuracy: 0.9857
# Epoch 68/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0548 - accuracy: 0.9815 - val_loss: 0.0461 - val_accuracy: 0.9848
# Epoch 69/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0534 - accuracy: 0.9820 - val_loss: 0.0459 - val_accuracy: 0.9842
# Epoch 70/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0531 - accuracy: 0.9828 - val_loss: 0.0458 - val_accuracy: 0.9863
# Epoch 71/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0516 - accuracy: 0.9827 - val_loss: 0.0452 - val_accuracy: 0.9852
# Epoch 72/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0522 - accuracy: 0.9826 - val_loss: 0.0450 - val_accuracy: 0.9867
# Epoch 73/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0554 - accuracy: 0.9809 - val_loss: 0.0448 - val_accuracy: 0.9859
# Epoch 74/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0527 - accuracy: 0.9825 - val_loss: 0.0446 - val_accuracy: 0.9862
# Epoch 75/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0509 - accuracy: 0.9833 - val_loss: 0.0449 - val_accuracy: 0.9858
# Epoch 76/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0514 - accuracy: 0.9828 - val_loss: 0.0436 - val_accuracy: 0.9864
# Epoch 77/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0504 - accuracy: 0.9834 - val_loss: 0.0436 - val_accuracy: 0.9862
# Epoch 78/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 0.0436 - val_accuracy: 0.9860
# Epoch 79/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0491 - accuracy: 0.9832 - val_loss: 0.0432 - val_accuracy: 0.9864
# Epoch 80/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0488 - accuracy: 0.9837 - val_loss: 0.0427 - val_accuracy: 0.9866
# Epoch 81/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0487 - accuracy: 0.9836 - val_loss: 0.0427 - val_accuracy: 0.9865
# Epoch 82/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0502 - accuracy: 0.9827 - val_loss: 0.0427 - val_accuracy: 0.9864
# Epoch 83/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0483 - accuracy: 0.9840 - val_loss: 0.0433 - val_accuracy: 0.9857
# Epoch 84/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0487 - accuracy: 0.9838 - val_loss: 0.0426 - val_accuracy: 0.9868
# Epoch 85/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.0418 - val_accuracy: 0.9867
# Epoch 86/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.0419 - val_accuracy: 0.9867
# Epoch 87/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0469 - accuracy: 0.9841 - val_loss: 0.0414 - val_accuracy: 0.9874
# Epoch 88/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0474 - accuracy: 0.9834 - val_loss: 0.0417 - val_accuracy: 0.9867
# Epoch 89/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0486 - accuracy: 0.9837 - val_loss: 0.0425 - val_accuracy: 0.9867
# Epoch 90/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0473 - accuracy: 0.9841 - val_loss: 0.0410 - val_accuracy: 0.9873
# Epoch 91/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0462 - accuracy: 0.9845 - val_loss: 0.0406 - val_accuracy: 0.9872
# Epoch 92/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0479 - accuracy: 0.9836 - val_loss: 0.0416 - val_accuracy: 0.9869
# Epoch 93/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0458 - accuracy: 0.9844 - val_loss: 0.0418 - val_accuracy: 0.9858
# Epoch 94/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0494 - accuracy: 0.9831 - val_loss: 0.0417 - val_accuracy: 0.9852
# Epoch 95/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0462 - accuracy: 0.9841 - val_loss: 0.0407 - val_accuracy: 0.9872
# Epoch 96/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0475 - accuracy: 0.9839 - val_loss: 0.0404 - val_accuracy: 0.9871
# Epoch 97/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0453 - accuracy: 0.9848 - val_loss: 0.0406 - val_accuracy: 0.9857
# Epoch 98/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0459 - accuracy: 0.9845 - val_loss: 0.0405 - val_accuracy: 0.9869
# Epoch 99/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.0406 - val_accuracy: 0.9862
# Epoch 100/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0465 - accuracy: 0.9843 - val_loss: 0.0405 - val_accuracy: 0.9871

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 929/929 [==============================] - 3s 3ms/step - loss: 0.0418 - accuracy: 0.9870
# Test results - Loss: 0.04184119403362274 - Accuracy: 98.69714379310608%

# %% [markdown]
# ### Plot of Accuracy

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Plot of loss

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
