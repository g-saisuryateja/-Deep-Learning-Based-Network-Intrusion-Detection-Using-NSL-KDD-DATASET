# %% [markdown]
# # Network Intrusion Detection using LSTM

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from keras.utils.vis_utils import plot_model

# %% [markdown]
# ### Reading Data

# %%
#Add the column labels
feature=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count", 
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

# %% [markdown]
# ### Fetching the files

# %%
train='KDDTrain+.txt'
test='KDDTest+.txt'
test21='KDDTest-21.txt'

train_data=pd.read_csv(train,names=feature)
test_data=pd.read_csv(test,names=feature)
test_data21 = pd.read_csv(test21, names= feature)
data= pd.concat([train_data, test_data], ignore_index=True)

# %%
data.head(5)
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      label  difficulty
# 0   normal          20
# 1   normal          15
# 2  neptune          19
# 3   normal          21
# 4   normal          21
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Exploring Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
#  42  difficulty                   148517 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 48.7+ MB

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 47.6+ MB

# %%
data.describe().T
# Out:
#                                 count          mean           std  min    25%  \
# duration                     148517.0    276.779305  2.460683e+03  0.0   0.00
# src_bytes                    148517.0  40227.949299  5.409612e+06  0.0   0.00
# dst_bytes                    148517.0  17088.853593  3.703525e+06  0.0   0.00
# land                         148517.0      0.000215  1.467714e-02  0.0   0.00
# wrong_fragment               148517.0      0.020523  2.400691e-01  0.0   0.00
# urgent                       148517.0      0.000202  1.941708e-02  0.0   0.00
# hot                          148517.0      0.189379  2.013160e+00  0.0   0.00
# num_failed_logins            148517.0      0.004323  7.224823e-02  0.0   0.00
# logged_in                    148517.0      0.402789  4.904606e-01  0.0   0.00
# num_compromised              148517.0      0.255062  2.223137e+01  0.0   0.00
# root_shell                   148517.0      0.001508  3.880696e-02  0.0   0.00
# su_attempted                 148517.0      0.000976  4.238907e-02  0.0   0.00
# num_root                     148517.0      0.273726  2.268902e+01  0.0   0.00
# num_file_creations           148517.0      0.012073  5.178631e-01  0.0   0.00
# num_shells                   148517.0      0.000525  2.770051e-02  0.0   0.00
# num_access_files             148517.0      0.004013  9.525663e-02  0.0   0.00
# num_outbound_cmds            148517.0      0.000000  0.000000e+00  0.0   0.00
# is_host_login                148517.0      0.000081  8.988484e-03  0.0   0.00
# is_guest_login               148517.0      0.012308  1.102585e-01  0.0   0.00
# count                        148517.0     83.336561  1.167607e+02  0.0   2.00
# srv_count                    148517.0     28.251937  7.536963e+01  0.0   2.00
# serror_rate                  148517.0      0.256925  4.319178e-01  0.0   0.00
# srv_serror_rate              148517.0      0.255337  4.325783e-01  0.0   0.00
# rerror_rate                  148517.0      0.137947  3.393872e-01  0.0   0.00
# srv_rerror_rate              148517.0      0.138487  3.417829e-01  0.0   0.00
# same_srv_rate                148517.0      0.672983  4.365437e-01  0.0   0.10
# diff_srv_rate                148517.0      0.067761  1.946658e-01  0.0   0.00
# srv_diff_host_rate           148517.0      0.097441  2.588856e-01  0.0   0.00
# dst_host_count               148517.0    183.928042  9.852833e+01  0.0  87.00
# dst_host_srv_count           148517.0    119.462661  1.112323e+02  0.0  11.00
# dst_host_same_srv_rate       148517.0      0.534521  4.480612e-01  0.0   0.05
# dst_host_diff_srv_rate       148517.0      0.084103  1.941020e-01  0.0   0.00
# dst_host_same_src_port_rate  148517.0      0.145932  3.086376e-01  0.0   0.00
# dst_host_srv_diff_host_rate  148517.0      0.030584  1.089751e-01  0.0   0.00
# dst_host_serror_rate         148517.0      0.256122  4.284996e-01  0.0   0.00
# dst_host_srv_serror_rate     148517.0      0.251304  4.297194e-01  0.0   0.00
# dst_host_rerror_rate         148517.0      0.136220  3.227411e-01  0.0   0.00
# dst_host_srv_rerror_rate     148517.0      0.136397  3.352823e-01  0.0   0.00
#
#                                 50%     75%           max
# duration                       0.00    0.00  5.771500e+04
# src_bytes                     44.00  278.00  1.379964e+09
# dst_bytes                      0.00  571.00  1.309937e+09
# land                           0.00    0.00  1.000000e+00
# wrong_fragment                 0.00    0.00  3.000000e+00
# urgent                         0.00    0.00  3.000000e+00
# hot                            0.00    0.00  1.010000e+02
# num_failed_logins              0.00    0.00  5.000000e+00
# logged_in                      0.00    1.00  1.000000e+00
# num_compromised                0.00    0.00  7.479000e+03
# root_shell                     0.00    0.00  1.000000e+00
# su_attempted                   0.00    0.00  2.000000e+00
# num_root                       0.00    0.00  7.468000e+03
# num_file_creations             0.00    0.00  1.000000e+02
# num_shells                     0.00    0.00  5.000000e+00
# num_access_files               0.00    0.00  9.000000e+00
# num_outbound_cmds              0.00    0.00  0.000000e+00
# is_host_login                  0.00    0.00  1.000000e+00
# is_guest_login                 0.00    0.00  1.000000e+00
# count                         13.00  141.00  5.110000e+02
# srv_count                      7.00   17.00  5.110000e+02
# serror_rate                    0.00    0.85  1.000000e+00
# srv_serror_rate                0.00    0.91  1.000000e+00
# rerror_rate                    0.00    0.00  1.000000e+00
# srv_rerror_rate                0.00    0.00  1.000000e+00
# same_srv_rate                  1.00    1.00  1.000000e+00
# diff_srv_rate                  0.00    0.06  1.000000e+00
# srv_diff_host_rate             0.00    0.00  1.000000e+00
# dst_host_count               255.00  255.00  2.550000e+02
# dst_host_srv_count            72.00  255.00  2.550000e+02
# dst_host_same_srv_rate         0.60    1.00  1.000000e+00
# dst_host_diff_srv_rate         0.02    0.07  1.000000e+00
# dst_host_same_src_port_rate    0.00    0.05  1.000000e+00
# dst_host_srv_diff_host_rate    0.00    0.01  1.000000e+00
# dst_host_serror_rate           0.00    0.60  1.000000e+00
# dst_host_srv_serror_rate       0.00    0.50  1.000000e+00
# dst_host_rerror_rate           0.00    0.00  1.000000e+00
# dst_host_srv_rerror_rate       0.00    0.00  1.000000e+00

# %%
# number of attack labels 
data['label'].value_counts()
# Out:
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: label, dtype: int64

# %% [markdown]
# ### Redistribute across common attack class

# %%
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# normal    77054
# Dos       53387
# Probe     14077
# R2L        3880
# U2R         119
# Name: label, dtype: int64

# %% [markdown]
# ### Creating Multi-class labels

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
label = pd.DataFrame(data.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = label.apply(le2.fit_transform)
data['intrusion'] = enc_label
print(data.shape)
data.head(5)
# Out:
# (148517, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes     land  \
# 0 -0.112481           tcp  ftp_data   SF  -0.007346  -0.004614 -0.01468
# 1 -0.112481           udp     other   SF  -0.007409  -0.004614 -0.01468
# 2 -0.112481           tcp   private   S0  -0.007436  -0.004614 -0.01468
# 3 -0.112481           tcp      http   SF  -0.007394  -0.002413 -0.01468
# 4 -0.112481           tcp      http   SF  -0.007400  -0.004501 -0.01468
#
#    wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0       -0.085488 -0.010403 -0.094071  ...               -0.813554
# 1       -0.085488 -0.010403 -0.094071  ...               -1.192968
# 2       -0.085488 -0.010403 -0.094071  ...               -0.969783
# 3       -0.085488 -0.010403 -0.094071  ...                1.038878
# 4       -0.085488 -0.010403 -0.094071  ...                1.038878
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0               -0.278736                     0.077981
# 1                2.657874                     2.378421
# 2               -0.175697                    -0.472829
# 3               -0.433294                    -0.375627
# 4               -0.433294                    -0.472829
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                    -0.280650             -0.597720
# 1                    -0.280650             -0.597720
# 2                    -0.280650              1.736012
# 3                     0.086408             -0.527708
# 4                    -0.280650             -0.597720
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                 -0.584813             -0.267151                 -0.406815
# 1                 -0.584813             -0.422074                 -0.406815
# 2                  1.742295             -0.422074                 -0.406815
# 3                 -0.561542             -0.422074                 -0.376989
# 4                 -0.584813             -0.422074                 -0.406815
#
#     label  intrusion
# 0  normal          4
# 1  normal          4
# 2     Dos          0
# 3  normal          4
# 4  normal          4
#
# [5 rows x 43 columns]

# %%
data.drop(labels= ['label'], axis=1, inplace=True)
print(data.shape)
# Out:
# (148517, 42)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")  
print(data.shape)
# Out:
# (148517, 123)

# %%
y_data= data['intrusion']
X_data= data.drop(labels=['intrusion'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (148517, 122)
# y_train has shape: (148517,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
# splitting the dataset 80% for training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (118813, 122)
#  (29704, 122)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %% [markdown]
# ### Applying LSTM Algorithms

# %%
model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))

# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 64)             47872
#
#  dropout (Dropout)           (None, 1, 64)             0
#
#  lstm_1 (LSTM)               (None, 1, 64)             33024
#
#  dropout_1 (Dropout)         (None, 1, 64)             0
#
#  lstm_2 (LSTM)               (None, 1, 64)             33024
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 117,425
# Trainable params: 117,425
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  Training the model

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 40s 581ms/step - loss: 1.5202 - accuracy: 0.7880 - val_loss: 1.3400 - val_accuracy: 0.8419
# Epoch 2/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.9689 - accuracy: 0.8423 - val_loss: 0.5256 - val_accuracy: 0.8422
# Epoch 3/100
# 20/20 [==============================] - 4s 213ms/step - loss: 0.4644 - accuracy: 0.8462 - val_loss: 0.3995 - val_accuracy: 0.8507
# Epoch 4/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.3668 - accuracy: 0.8857 - val_loss: 0.3200 - val_accuracy: 0.9188
# Epoch 5/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.2815 - accuracy: 0.9302 - val_loss: 0.2343 - val_accuracy: 0.9386
# Epoch 6/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.2172 - accuracy: 0.9392 - val_loss: 0.1956 - val_accuracy: 0.9432
# Epoch 7/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1881 - accuracy: 0.9439 - val_loss: 0.1725 - val_accuracy: 0.9466
# Epoch 8/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1672 - accuracy: 0.9473 - val_loss: 0.1542 - val_accuracy: 0.9488
# Epoch 9/100
# 20/20 [==============================] - 4s 212ms/step - loss: 0.1480 - accuracy: 0.9498 - val_loss: 0.1368 - val_accuracy: 0.9519
# Epoch 10/100
# 20/20 [==============================] - 5s 232ms/step - loss: 0.1319 - accuracy: 0.9531 - val_loss: 0.1205 - val_accuracy: 0.9572
# Epoch 11/100
# 20/20 [==============================] - 4s 214ms/step - loss: 0.1176 - accuracy: 0.9584 - val_loss: 0.1076 - val_accuracy: 0.9619
# Epoch 12/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1064 - accuracy: 0.9617 - val_loss: 0.0968 - val_accuracy: 0.9661
# Epoch 13/100
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0975 - accuracy: 0.9644 - val_loss: 0.0893 - val_accuracy: 0.9680
# Epoch 14/100
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0902 - accuracy: 0.9684 - val_loss: 0.0823 - val_accuracy: 0.9731
# Epoch 15/100
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0843 - accuracy: 0.9715 - val_loss: 0.0771 - val_accuracy: 0.9762
# Epoch 16/100
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0798 - accuracy: 0.9729 - val_loss: 0.0721 - val_accuracy: 0.9768
# Epoch 17/100
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0746 - accuracy: 0.9744 - val_loss: 0.0684 - val_accuracy: 0.9786
# Epoch 18/100
# 20/20 [==============================] - 4s 210ms/step - loss: 0.0714 - accuracy: 0.9755 - val_loss: 0.0640 - val_accuracy: 0.9807
# Epoch 19/100
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0687 - accuracy: 0.9766 - val_loss: 0.0615 - val_accuracy: 0.9801
# Epoch 20/100
# 20/20 [==============================] - 4s 205ms/step - loss: 0.0648 - accuracy: 0.9773 - val_loss: 0.0588 - val_accuracy: 0.9814
# Epoch 21/100
# 20/20 [==============================] - 4s 203ms/step - loss: 0.0625 - accuracy: 0.9786 - val_loss: 0.0563 - val_accuracy: 0.9819
# Epoch 22/100
# 20/20 [==============================] - 4s 212ms/step - loss: 0.0601 - accuracy: 0.9799 - val_loss: 0.0546 - val_accuracy: 0.9825
# Epoch 23/100
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0584 - accuracy: 0.9797 - val_loss: 0.0531 - val_accuracy: 0.9843
# Epoch 24/100
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0587 - accuracy: 0.9798 - val_loss: 0.0524 - val_accuracy: 0.9827
# Epoch 25/100
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0563 - accuracy: 0.9811 - val_loss: 0.0510 - val_accuracy: 0.9843
# Epoch 26/100
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0547 - accuracy: 0.9818 - val_loss: 0.0496 - val_accuracy: 0.9836
# Epoch 27/100
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0542 - accuracy: 0.9818 - val_loss: 0.0491 - val_accuracy: 0.9840
# Epoch 28/100
# 20/20 [==============================] - 4s 206ms/step - loss: 0.0537 - accuracy: 0.9825 - val_loss: 0.0479 - val_accuracy: 0.9850
# Epoch 29/100
# 20/20 [==============================] - 4s 212ms/step - loss: 0.0518 - accuracy: 0.9824 - val_loss: 0.0468 - val_accuracy: 0.9849
# Epoch 30/100
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0506 - accuracy: 0.9832 - val_loss: 0.0464 - val_accuracy: 0.9854
# Epoch 31/100
# 20/20 [==============================] - 4s 209ms/step - loss: 0.0513 - accuracy: 0.9827 - val_loss: 0.0461 - val_accuracy: 0.9852
# Epoch 32/100
# 20/20 [==============================] - 4s 200ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 0.0450 - val_accuracy: 0.9862
# Epoch 33/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.0493 - accuracy: 0.9835 - val_loss: 0.0447 - val_accuracy: 0.9852
# Epoch 34/100
# 20/20 [==============================] - 3s 146ms/step - loss: 0.0478 - accuracy: 0.9837 - val_loss: 0.0436 - val_accuracy: 0.9861
# Epoch 35/100
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0475 - accuracy: 0.9843 - val_loss: 0.0433 - val_accuracy: 0.9867
# Epoch 36/100
# 20/20 [==============================] - 3s 149ms/step - loss: 0.0465 - accuracy: 0.9842 - val_loss: 0.0439 - val_accuracy: 0.9859
# Epoch 37/100
# 20/20 [==============================] - 3s 151ms/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 0.0431 - val_accuracy: 0.9854
# Epoch 38/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0458 - accuracy: 0.9849 - val_loss: 0.0426 - val_accuracy: 0.9864
# Epoch 39/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0460 - accuracy: 0.9846 - val_loss: 0.0429 - val_accuracy: 0.9863
# Epoch 40/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0454 - accuracy: 0.9848 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 41/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.0442 - accuracy: 0.9850 - val_loss: 0.0415 - val_accuracy: 0.9863
# Epoch 42/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0435 - accuracy: 0.9852 - val_loss: 0.0407 - val_accuracy: 0.9869
# Epoch 43/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0434 - accuracy: 0.9852 - val_loss: 0.0405 - val_accuracy: 0.9866
# Epoch 44/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0435 - accuracy: 0.9856 - val_loss: 0.0407 - val_accuracy: 0.9862
# Epoch 45/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0428 - accuracy: 0.9858 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 46/100
# 20/20 [==============================] - 3s 147ms/step - loss: 0.0418 - accuracy: 0.9858 - val_loss: 0.0397 - val_accuracy: 0.9868
# Epoch 47/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 0.0401 - val_accuracy: 0.9878
# Epoch 48/100
# 20/20 [==============================] - 3s 128ms/step - loss: 0.0419 - accuracy: 0.9859 - val_loss: 0.0397 - val_accuracy: 0.9875
# Epoch 49/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0435 - accuracy: 0.9854 - val_loss: 0.0399 - val_accuracy: 0.9880
# Epoch 50/100
# 20/20 [==============================] - 3s 128ms/step - loss: 0.0411 - accuracy: 0.9862 - val_loss: 0.0395 - val_accuracy: 0.9870
# Epoch 51/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0415 - accuracy: 0.9862 - val_loss: 0.0389 - val_accuracy: 0.9879
# Epoch 52/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0421 - accuracy: 0.9855 - val_loss: 0.0396 - val_accuracy: 0.9864
# Epoch 53/100
# 20/20 [==============================] - 2s 125ms/step - loss: 0.0400 - accuracy: 0.9862 - val_loss: 0.0385 - val_accuracy: 0.9878
# Epoch 54/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.0383 - val_accuracy: 0.9880
# Epoch 55/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0395 - accuracy: 0.9869 - val_loss: 0.0379 - val_accuracy: 0.9881
# Epoch 56/100
# 20/20 [==============================] - 3s 143ms/step - loss: 0.0392 - accuracy: 0.9866 - val_loss: 0.0384 - val_accuracy: 0.9877
# Epoch 57/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.0419 - accuracy: 0.9857 - val_loss: 0.0389 - val_accuracy: 0.9883
# Epoch 58/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0404 - accuracy: 0.9864 - val_loss: 0.0383 - val_accuracy: 0.9877
# Epoch 59/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.0395 - accuracy: 0.9861 - val_loss: 0.0382 - val_accuracy: 0.9878
# Epoch 60/100
# 20/20 [==============================] - 3s 141ms/step - loss: 0.0387 - accuracy: 0.9871 - val_loss: 0.0372 - val_accuracy: 0.9883
# Epoch 61/100
# 20/20 [==============================] - 3s 153ms/step - loss: 0.0385 - accuracy: 0.9871 - val_loss: 0.0371 - val_accuracy: 0.9883
# Epoch 62/100
# 20/20 [==============================] - 3s 131ms/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 0.0371 - val_accuracy: 0.9880
# Epoch 63/100
# 20/20 [==============================] - 4s 226ms/step - loss: 0.0374 - accuracy: 0.9876 - val_loss: 0.0371 - val_accuracy: 0.9886
# Epoch 64/100
# 20/20 [==============================] - 3s 127ms/step - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.0369 - val_accuracy: 0.9883
# Epoch 65/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0374 - accuracy: 0.9876 - val_loss: 0.0362 - val_accuracy: 0.9888
# Epoch 66/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0370 - val_accuracy: 0.9883
# Epoch 67/100
# 20/20 [==============================] - 3s 149ms/step - loss: 0.0387 - accuracy: 0.9866 - val_loss: 0.0374 - val_accuracy: 0.9883
# Epoch 68/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0377 - accuracy: 0.9873 - val_loss: 0.0365 - val_accuracy: 0.9882
# Epoch 69/100
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0382 - accuracy: 0.9869 - val_loss: 0.0368 - val_accuracy: 0.9873
# Epoch 70/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.0370 - accuracy: 0.9875 - val_loss: 0.0357 - val_accuracy: 0.9890
# Epoch 71/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0364 - accuracy: 0.9877 - val_loss: 0.0357 - val_accuracy: 0.9887
# Epoch 72/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.0355 - accuracy: 0.9878 - val_loss: 0.0356 - val_accuracy: 0.9889
# Epoch 73/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0364 - accuracy: 0.9875 - val_loss: 0.0355 - val_accuracy: 0.9883
# Epoch 74/100
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0375 - accuracy: 0.9870 - val_loss: 0.0355 - val_accuracy: 0.9893
# Epoch 75/100
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0351 - accuracy: 0.9881 - val_loss: 0.0355 - val_accuracy: 0.9881
# Epoch 76/100
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 0.0354 - val_accuracy: 0.9890
# Epoch 77/100
# 20/20 [==============================] - 3s 151ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 0.0349 - val_accuracy: 0.9895
# Epoch 78/100
# 20/20 [==============================] - 3s 149ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.0350 - val_accuracy: 0.9887
# Epoch 79/100
# 20/20 [==============================] - 3s 127ms/step - loss: 0.0355 - accuracy: 0.9880 - val_loss: 0.0353 - val_accuracy: 0.9888
# Epoch 80/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0353 - accuracy: 0.9883 - val_loss: 0.0349 - val_accuracy: 0.9888
# Epoch 81/100
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.0347 - val_accuracy: 0.9886
# Epoch 82/100
# 20/20 [==============================] - 3s 151ms/step - loss: 0.0348 - accuracy: 0.9883 - val_loss: 0.0344 - val_accuracy: 0.9893
# Epoch 83/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 0.0343 - val_accuracy: 0.9889
# Epoch 84/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.0340 - accuracy: 0.9887 - val_loss: 0.0344 - val_accuracy: 0.9894
# Epoch 85/100
# 20/20 [==============================] - 3s 149ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.0345 - val_accuracy: 0.9895
# Epoch 86/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.0338 - accuracy: 0.9885 - val_loss: 0.0341 - val_accuracy: 0.9891
# Epoch 87/100
# 20/20 [==============================] - 2s 125ms/step - loss: 0.0335 - accuracy: 0.9891 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 88/100
# 20/20 [==============================] - 3s 151ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.0337 - val_accuracy: 0.9898
# Epoch 89/100
# 20/20 [==============================] - 3s 146ms/step - loss: 0.0333 - accuracy: 0.9888 - val_loss: 0.0342 - val_accuracy: 0.9881
# Epoch 90/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0338 - accuracy: 0.9888 - val_loss: 0.0338 - val_accuracy: 0.9896
# Epoch 91/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.0339 - val_accuracy: 0.9893
# Epoch 92/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 93/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.0352 - accuracy: 0.9879 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 94/100
# 20/20 [==============================] - 3s 144ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.0335 - val_accuracy: 0.9899
# Epoch 95/100
# 20/20 [==============================] - 3s 130ms/step - loss: 0.0322 - accuracy: 0.9891 - val_loss: 0.0337 - val_accuracy: 0.9889
# Epoch 96/100
# 20/20 [==============================] - 2s 126ms/step - loss: 0.0336 - accuracy: 0.9886 - val_loss: 0.0334 - val_accuracy: 0.9900
# Epoch 97/100
# 20/20 [==============================] - 3s 130ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0334 - val_accuracy: 0.9897
# Epoch 98/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 0.0336 - val_accuracy: 0.9897
# Epoch 99/100
# 20/20 [==============================] - 3s 129ms/step - loss: 0.0332 - accuracy: 0.9886 - val_loss: 0.0333 - val_accuracy: 0.9898
# Epoch 100/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 0.0335 - val_accuracy: 0.9890

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 929/929 [==============================] - 3s 3ms/step - loss: 0.0360 - accuracy: 0.9874
# Test results - Loss: 0.03601311519742012 - Accuracy: 98.73754382133484%

# %% [markdown]
# ### Plot of Accuracy

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Plot of loss

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
